# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#-------------------------------- ctn1 1mM--------------------------------------------------------------

ctn1_1 = pd.read_csv('Datos/06 10/ctn1_10mM.csv', delimiter=';')

t = list(ctn1_1['Tiempo'])
I_1_10 = np.array(ctn1_1['Intensidad'])
maxa = np.max(I_1_10)
I_1_10 = list(ctn1_1['Intensidad'])/maxa
d_1_10 = list(ctn1_1['Incertidumbre'])
T_1_10 = list(ctn1_1['Temperatura'])

Tprom = np.mean(T_1_10)

#-------------------------------- ctn1 1mM 2--------------------------------------------------------------

ctn1_1_1 = pd.read_csv('Datos/06 10/ctn1_10mM_1.csv', delimiter=';')

t_1 = list(ctn1_1_1['Tiempo'])
I_1_10_1 = list(ctn1_1_1['Intensidad'])
maxa = np.max(I_1_10_1)
I_1_10_1 = list(ctn1_1_1['Intensidad'])/maxa
d_1_10_1 = list(ctn1_1_1['Incertidumbre'])
T_1_10_1 = list(ctn1_1_1['Temperatura'])

t_1_1 = t_1

#-------------------------------- ctn1 1mM 3--------------------------------------------------------------

ctn1_1_2 = pd.read_csv('Datos/06 10/ctn1_10mM_2.csv', delimiter=';')

t_2 = list(ctn1_1_2['Tiempo'])
I_1_10_2 = list(ctn1_1_2['Intensidad'])
maxa = np.max(I_1_10_2)
I_1_10_2 = list(ctn1_1_2['Intensidad'])/maxa
d_1_10_2 = list(ctn1_1_2['Incertidumbre'])
T_1_10_2 = list(ctn1_1_2['Temperatura'])

#-------------------------------- ctn2 1mM--------------------------------------------------------------

ctn2_1 = pd.read_csv('Datos/06 10/ctn2_10mM.csv', delimiter=';')

t_3 = list(ctn2_1['Tiempo'])
I_2_10 = list(ctn2_1['Intensidad'])
maxa = np.max(I_2_10)
I_2_10 = list(ctn2_1['Intensidad'])/maxa
d_2_10 = list(ctn2_1['Incertidumbre'])
T_2_10 = list(ctn2_1['Temperatura'])

Tprom = np.mean(T_2_10)

#-------------------------------- ctn2 1mM 2--------------------------------------------------------------

ctn2_1_1 = pd.read_csv('Datos/06 10/ctn2_10mM_1.csv', delimiter=';')

t_4 = list(ctn2_1_1['Tiempo'])
I_2_10_1 = list(ctn2_1_1['Intensidad'])
maxa = np.max(I_2_10_1)
I_2_10_1 = list(ctn2_1_1['Intensidad'])/maxa
d_2_10_1 = list(ctn2_1_1['Incertidumbre'])
T_2_10_1 = list(ctn2_1_1['Temperatura'])

#-------------------------------- ctn2 1mM 3--------------------------------------------------------------

ctn2_1_2 = pd.read_csv('Datos/06 10/ctn2_10mM_2.csv', delimiter=';')

t_5 = list(ctn2_1_2['Tiempo'])
I_2_10_2 = list(ctn2_1_2['Intensidad'])
maxa = np.max(I_2_10_2)
I_2_10_2 = list(ctn2_1_2['Intensidad'])/maxa
d_2_10_2 = list(ctn2_1_2['Incertidumbre'])
T_2_10_2 = list(ctn2_1_2['Temperatura'])

t_5_1=t_5

#-------------------------------- ctn3 1mM--------------------------------------------------------------

ctn3_1 = pd.read_csv('Datos/06 10/ctn3_10mM.csv', delimiter=';')

t_6 = list(ctn3_1['Tiempo'])
I_3_10 = np.array(ctn3_1['Intensidad'])
maxa = np.max(I_3_10)
I_3_10 = list(ctn3_1['Intensidad'])/maxa
d_3_10 = list(ctn3_1['Incertidumbre'])
T_3_10 = list(ctn3_1['Temperatura'])

Tprom = np.mean(T_3_10)

#-------------------------------- ctn3 1mM 2--------------------------------------------------------------

ctn3_1_1 = pd.read_csv('Datos/06 10/ctn3_10mM_1.csv', delimiter=';')

t_7 = list(ctn3_1_1['Tiempo'])
I_3_10_1 = list(ctn3_1_1['Intensidad'])
maxa = np.max(I_3_10_1)
I_3_10_1 = list(ctn3_1_1['Intensidad'])/maxa
d_3_10_1 = list(ctn3_1_1['Incertidumbre'])
T_3_10_1 = list(ctn3_1_1['Temperatura'])

#-------------------------------- ctn3 1mM 3--------------------------------------------------------------

ctn3_1_2 = pd.read_csv('Datos/06 10/ctn3_10mM_2.csv', delimiter=';')

t_8 = list(ctn3_1_2['Tiempo'])
I_3_10_2 = list(ctn3_1_2['Intensidad'])
maxa = np.max(I_3_10_2)
I_3_10_2 = list(ctn3_1_2['Intensidad'])/maxa
d_3_10_2 = list(ctn3_1_2['Incertidumbre'])
T_3_10_2 = list(ctn3_1_2['Temperatura'])

#-------------------------------- ctn4 1mM--------------------------------------------------------------

ctn4_1 = pd.read_csv('Datos/06 10/ctn4_10mM.csv', delimiter=';')

t_9 = list(ctn4_1['Tiempo'])
I_4_10 = np.array(ctn4_1['Intensidad'])
maxa = np.max(I_4_10)
I_4_10 = list(ctn4_1['Intensidad'])/maxa
d_4_10 = list(ctn4_1['Incertidumbre'])
T_4_10 = list(ctn4_1['Temperatura'])

Tprom = np.mean(T_4_10)

#-------------------------------- ctn4 1mM 2--------------------------------------------------------------

ctn4_1_1 = pd.read_csv('Datos/06 10/ctn4_10mM_1.csv', delimiter=';')

t_10 = list(ctn4_1_1['Tiempo'])
I_4_10_1 = list(ctn4_1_1['Intensidad'])
maxa = np.max(I_4_10_1)
I_4_10_1 = list(ctn4_1_1['Intensidad'])/maxa
d_4_10_1 = list(ctn4_1_1['Incertidumbre'])
T_4_10_1 = list(ctn4_1_1['Temperatura'])

#-------------------------------- ctn4 1mM 3--------------------------------------------------------------

ctn4_1_2 = pd.read_csv('Datos/06 10/ctn4_10mM_2.csv', delimiter=';')

t_11 = list(ctn4_1_2['Tiempo'])
I_4_10_2 = list(ctn4_1_2['Intensidad'])
maxa = np.max(I_4_10_2)
I_4_10_2 = list(ctn4_1_2['Intensidad'])/maxa
d_4_10_2 = list(ctn4_1_2['Incertidumbre'])
T_4_10_2 = list(ctn4_1_2['Temperatura'])

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.plot(t, I_1_10, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_1, I_1_10_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_2, I_1_10_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(10mM)')
plt.savefig('ctn1_10.png')

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.plot(t_3, I_2_10, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_4, I_2_10_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_5, I_2_10_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(10mM)')
plt.savefig('ctn2_10.png')

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.plot(t_6, I_3_10, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_7, I_3_10_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_8, I_3_10_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(10mM)')
plt.savefig('ctn3_10.png')

# %%
plt.figure(figsize=(20,6))

#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,1)
plt.plot(t_9, I_4_10, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_10, I_4_10_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(10mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_11, I_4_10_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(10mM) '.format(Tprom))

plt.savefig('ctn4_10.png')

# %%
#-------------------------------- ctn1 1mM--------------------------------------------------------------

ctn1_1 = pd.read_csv('Datos/06 10/ctn1_1mM.csv', delimiter=';')

t = list(ctn1_1['Tiempo'])
I_1_1 = np.array(ctn1_1['Intensidad'])
maxa = np.max(I_1_1)
I_1_1 = list(ctn1_1['Intensidad'])/maxa
d_1_1 = list(ctn1_1['Incertidumbre'])
T_1_1 = list(ctn1_1['Temperatura'])

Tprom = np.mean(T_1_1)

#-------------------------------- ctn1 1mM 2--------------------------------------------------------------

ctn1_1_1 = pd.read_csv('Datos/06 10/ctn1_1mM_1.csv', delimiter=';')

t_1 = list(ctn1_1_1['Tiempo'])
I_1_1_1 = list(ctn1_1_1['Intensidad'])
maxa = np.max(I_1_1_1)
I_1_1_1 = list(ctn1_1_1['Intensidad'])/maxa
d_1_1_1 = list(ctn1_1_1['Incertidumbre'])
T_1_1_1 = list(ctn1_1_1['Temperatura'])

#-------------------------------- ctn1 1mM 3--------------------------------------------------------------

ctn1_1_2 = pd.read_csv('Datos/06 10/ctn1_1mM_2.csv', delimiter=';')

t_2 = list(ctn1_1_2['Tiempo'])
I_1_1_2 = list(ctn1_1_2['Intensidad'])
maxa = np.max(I_1_1_2)
I_1_1_2 = list(ctn1_1_2['Intensidad'])/maxa
d_1_1_2 = list(ctn1_1_2['Incertidumbre'])
T_1_1_2 = list(ctn1_1_2['Temperatura'])

#-------------------------------- ctn2 1mM--------------------------------------------------------------

ctn2_1 = pd.read_csv('Datos/06 10/ctn2_1mM.csv', delimiter=';')

t_3 = list(ctn2_1['Tiempo'])
I_2_1 = list(ctn2_1['Intensidad'])
maxa = np.max(I_2_1)
I_2_1 = list(ctn2_1['Intensidad'])/maxa
d_2_1 = list(ctn2_1['Incertidumbre'])
T_2_1 = list(ctn2_1['Temperatura'])

Tprom = np.mean(T_2_1)

#-------------------------------- ctn2 1mM 2--------------------------------------------------------------

ctn2_1_1 = pd.read_csv('Datos/06 10/ctn2_1mM_1.csv', delimiter=';')

t_4 = list(ctn2_1_1['Tiempo'])
I_2_1_1 = list(ctn2_1_1['Intensidad'])
maxa = np.max(I_2_1_1)
I_2_1_1 = list(ctn2_1_1['Intensidad'])/maxa
d_2_1_1 = list(ctn2_1_1['Incertidumbre'])
T_2_1_1 = list(ctn2_1_1['Temperatura'])

#-------------------------------- ctn2 1mM 3--------------------------------------------------------------

ctn2_1_2 = pd.read_csv('Datos/06 10/ctn2_1mM_2.csv', delimiter=';')

t_5 = list(ctn2_1_2['Tiempo'])
I_2_1_2 = list(ctn2_1_2['Intensidad'])
maxa = np.max(I_2_1_2)
I_2_1_2 = list(ctn2_1_2['Intensidad'])/maxa
d_2_1_2 = list(ctn2_1_2['Incertidumbre'])
T_2_1_2 = list(ctn2_1_2['Temperatura'])

#-------------------------------- ctn3 1mM--------------------------------------------------------------

ctn3_1 = pd.read_csv('Datos/06 10/ctn3_1mM.csv', delimiter=';')

t_6 = list(ctn3_1['Tiempo'])
I_3_1 = np.array(ctn3_1['Intensidad'])
maxa = np.max(I_3_1)
I_3_1 = list(ctn3_1['Intensidad'])/maxa
d_3_1 = list(ctn3_1['Incertidumbre'])
T_3_1 = list(ctn3_1['Temperatura'])

Tprom = np.mean(T_3_1)

#-------------------------------- ctn3 1mM 2--------------------------------------------------------------

ctn3_1_1 = pd.read_csv('Datos/06 10/ctn3_1mM_1.csv', delimiter=';')

t_7 = list(ctn3_1_1['Tiempo'])
I_3_1_1 = list(ctn3_1_1['Intensidad'])
maxa = np.max(I_3_1_1)
I_3_1_1 = list(ctn3_1_1['Intensidad'])/maxa
d_3_1_1 = list(ctn3_1_1['Incertidumbre'])
T_3_1_1 = list(ctn3_1_1['Temperatura'])

#-------------------------------- ctn3 1mM 3--------------------------------------------------------------

ctn3_1_2 = pd.read_csv('Datos/06 10/ctn3_1mM_2.csv', delimiter=';')

t_8 = list(ctn3_1_2['Tiempo'])
I_3_1_2 = list(ctn3_1_2['Intensidad'])
maxa = np.max(I_3_1_2)
I_3_1_2 = list(ctn3_1_2['Intensidad'])/maxa
d_3_1_2 = list(ctn3_1_2['Incertidumbre'])
T_3_1_2 = list(ctn3_1_2['Temperatura'])

#-------------------------------- ctn4 1mM--------------------------------------------------------------

ctn4_1 = pd.read_csv('Datos/06 10/ctn4_1mM.csv', delimiter=';')

t_9 = list(ctn4_1['Tiempo'])
I_4_1 = np.array(ctn4_1['Intensidad'])
maxa = np.max(I_4_1)
I_4_1 = list(ctn4_1['Intensidad'])/maxa
d_4_1 = list(ctn4_1['Incertidumbre'])
T_4_1 = list(ctn4_1['Temperatura'])

Tprom = np.mean(T_4_1)

#-------------------------------- ctn4 1mM 2--------------------------------------------------------------

ctn4_1_1 = pd.read_csv('Datos/06 10/ctn4_1mM_1.csv', delimiter=';')

t_1 = list(ctn4_1_1['Tiempo'])
I_4_1_1 = list(ctn4_1_1['Intensidad'])
maxa = np.max(I_4_1_1)
I_4_1_1 = list(ctn4_1_1['Intensidad'])/maxa
d_4_1_1 = list(ctn4_1_1['Incertidumbre'])
T_4_1_1 = list(ctn4_1_1['Temperatura'])

#-------------------------------- ctn4 1mM 3--------------------------------------------------------------

ctn4_1_2 = pd.read_csv('Datos/06 10/ctn4_1mM_2.csv', delimiter=';')

t_11 = list(ctn4_1_2['Tiempo'])
I_4_1_2 = list(ctn4_1_2['Intensidad'])
maxa = np.max(I_4_1_2)
I_4_1_2 = list(ctn4_1_2['Intensidad'])/maxa
d_4_1_2 = list(ctn4_1_2['Incertidumbre'])
T_4_1_2 = list(ctn4_1_2['Temperatura'])

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.plot(t, I_1_1, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_1, I_1_1_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_2, I_1_1_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(1mM)')
plt.savefig('ctn1_1.png')

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.plot(t, I_2_1, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_1, I_2_1_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_2, I_2_1_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(1mM)')
plt.savefig('ctn2_1.png')

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.plot(t, I_3_1, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_1, I_3_1_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_2, I_3_1_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(1mM)')
plt.savefig('ctn3_1.png')

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.plot(t, I_4_1, label = 'Repetición 1')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,2)
plt.plot(t_1, I_4_1_1, label = 'Repetición 2')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(1mM) '.format(Tprom))
#----------------------------------------------------------------------------------------------------------
plt.subplot(1,3,3)
plt.plot(t_2, I_4_1_2, label = 'Repetición 3')
plt.legend()
#plt.grid()
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(1mM)')
plt.savefig('ctn4_1.png')

# %%
#Ctn4------------------------------------------------------------------------------------------------------------------

plt.figure(figsize=(15,6))

plt.subplot(1,2,1)

plt.plot(t, I_4_10_2, label = 'Repetición 3')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(10mM) ')

plt.subplot(1,2,2)

plt.plot(t, I_4_1, label = 'Repetición 1')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn4(1mM) ')

plt.savefig('ctn4_pre.png')

# %%
#Ctn3------------------------------------------------------------------------------------------------------------------

plt.figure(figsize=(15,6))

plt.subplot(1,2,1)

plt.plot(t_7, I_3_10_1, label = 'Repetición 2')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(10mM) ')

plt.subplot(1,2,2)

plt.plot(t, I_3_1, label = 'Repetición 1')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn3(1mM) ')

plt.savefig('ctn3_pre.png')

# %%
#Ctn2------------------------------------------------------------------------------------------------------------------

plt.figure(figsize=(15,6))

plt.subplot(1,2,1)

plt.plot(t_5_1, I_2_10_2, label = 'Repetición 3')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(10mM)')

plt.subplot(1,2,2)

plt.plot(t_1, I_2_1_1, label = 'Repetición 2')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn2(1mM) ')

plt.savefig('ctn2_pre.png')

# %%
#Ctn1------------------------------------------------------------------------------------------------------------------

plt.figure(figsize=(15,6))

plt.subplot(1,2,1)

plt.plot(t_1, I_1_1_1, label = 'Repetición 2')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(10mM) ')

plt.subplot(1,2,2)

plt.plot(t_1_1, I_1_10_1, label = 'Repetición 2')
plt.xlabel('Tiempo [s]')
plt.ylabel('Intensidad [u.a]')
plt.title('Intensidad en función del tiempo de buffer, \n liposomas y 10$\mu$l de ctn1(1mM) ')

plt.savefig('ctn1_pre.png')
